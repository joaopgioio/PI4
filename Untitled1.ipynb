# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from datetime import datetime, date

hoje = date.today()


ano = '22'
mes = '3'
dia = 15

opcoes = webdriver.FirefoxOptions()

opcoes.add_argument("--headless")
opcoes.add_argument("--disable-gpu")
opcoes.add_argument("enable-features=NetworkServiceInProcess")
opcoes.add_argument("--no-sandbox")

if (dia == 15):
    navegador = webdriver.Firefox(options=opcoes)
    
    navegador.get('https://www.ssp.sp.gov.br/transparenciassp/')
    #botao_roubo_celular = navegador.find_element(By.XPATH, "//a[@id='cphBody_btnRouboCelular']").click()
    botao_roubo_celular = navegador.find_element(By.ID, 'cphBody_btnRouboCelular').click()
    ano_roubo_celular = navegador.find_element(By.ID, 'cphBody_lkAno'+ano).click()
    mes_roubo_celular = navegador.find_element(By.ID, 'cphBody_lkMes'+mes).click()
    botao_export = navegador.find_element(By.ID, 'cphBody_ExportarBOLink').click()
    navegador.quit()

# %%
# !pip install squarify
# !pip install folium
# Out:
# Requirement already satisfied: squarify in d:\users\programas\anaconda3\lib\site-packages (0.4.3)
# Requirement already satisfied: folium in d:\users\programas\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy in d:\users\programas\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: jinja2>=2.9 in d:\users\programas\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: branca>=0.6.0 in d:\users\programas\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: requests in d:\users\programas\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\programas\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\users\programas\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\programas\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\programas\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\programas\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)

# %%
# IMPORTANDO BIBLIOTECAS

import pandas as pd
import glob
import re
import itertools
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import squarify

import matplotlib.pyplot as plt
import matplotlib
plt.style.use('fivethirtyeight')

import plotly.offline as py 
py.init_notebook_mode(connected=True) # this code, allow us to work with offline plotly version
import plotly.graph_objs as go # it's like "plt" of matplot
import plotly.tools as tls # It's useful to we get some tools of plotly

from folium import Map
from folium.plugins import HeatMap
from folium.plugins import FastMarkerCluster

import warnings
warnings.filterwarnings("ignore")

from selenium import webdriver
from selenium.webdriver.common.by import By
from datetime import datetime, date
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
file_ = 'data/DadosBO_2019_1(ROUBO DE CELULAR) teste.csv'
#file_ = 'data/teste1.csv'
cols = ['ANO_BO','DATAOCORRENCIA', 'PERIDOOCORRENCIA', 'BAIRRO', 'CIDADE', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO', \
           'DESCRICAOLOCAL', 'DESCR_TIPO_VEICULO']
df = pd.read_csv(file_, index_col=None, header=0, delimiter=';',usecols=cols)
#df = pd.read_csv(file_,index_col=None, header=0, sep=';',encoding='utf-8',  usecols=cols, error_bad_lines=False)
#df = pd.read_csv(file_,index_col=None, header=0, encoding="utf-8", sep=',', error_bad_lines=False)
df.head(50)
# Out:
#     ANO_BO DATAOCORRENCIA PERIDOOCORRENCIA  \
# 0     2018     31/12/2018          A NOITE
# 1     2018     31/12/2018          A NOITE
# 2     2018     31/12/2018          A NOITE
# 3     2018     31/12/2018          A NOITE
# 4     2018     31/12/2018          A NOITE
# 5     2018     31/12/2018          A NOITE
# 6     2018     31/12/2018          A NOITE
# 7     2018     31/12/2018          A NOITE
# 8     2018     31/12/2018          A NOITE
# 9     2018     31/12/2018          A NOITE
# 10    2018     31/12/2018          A NOITE
# 11    2018     31/12/2018          A NOITE
# 12    2018     30/12/2018          A NOITE
# 18  FERRAZ DE VASCONCELOS   -23,5159497   -46,3690849           Via Pública
# 19                S.PAULO  -23,54298316  -46,42066587           Via pública
# 20                 SUMARE  -22,80640663   -47,2176945           Via pública
# 21                S.PAULO  -23,51842347  -46,38789685           Via Pública
# 22                S.PAULO   -23,4590231   -46,7553369  Veículo em movimento
# 23                S.PAULO   -23,4590231   -46,7553369  Veículo em movimento
# 24                S.PAULO   -23,5241603   -46,6070422                Outros
# 25            CARAPICUIBA  -23,52136868  -46,82852116           Via pública
# 26            CARAPICUIBA  -23,52136868  -46,82852116           Via pública
# 27            CARAPICUIBA  -23,52136868  -46,82852116           Via pública
# 28            CARAPICUIBA  -23,52136868  -46,82852116           Via pública
# 29        ITAQUAQUECETUBA           NaN           NaN           Via Pública
# 30       FRANCISCO MORATO   -23,2808839   -46,7479212           Via Pública
# 31                UBATUBA  -23,46796491  -45,06939416           Via Pública
# 32             COSMOPOLIS  -22,63708075  -47,18959609           Via pública
# 33               CAMPINAS  -22,93608038  -47,07045601           Via pública
# 34                 OSASCO           NaN           NaN           Via Pública
# 35  FERRAZ DE VASCONCELOS  -23,53445101  -46,39370161           Via pública
# 36  FERRAZ DE VASCONCELOS  -23,53445101  -46,39370161           Via pública
# 37    S.BERNARDO DO CAMPO  -23,70546264  -46,55784683           Via pública
# 38    S.BERNARDO DO CAMPO  -23,70546264  -46,55784683           Via pública
# 39             MOGI GUACU           NaN           NaN            Residência
# 40                S.PAULO  -23,55629022  -46,70385054           Via pública
# 41                S.PAULO  -23,55629022  -46,70385054           Via pública
# 42                S.PAULO  -23,65174845  -46,78446905           Via pública
# 43                S.PAULO  -23,65174845  -46,78446905           Via pública
# 44       S.CAETANO DO SUL  -23,62684478  -46,55276941           Via pública
# 45              GUARULHOS  -23,48515397  -46,55350992   Comércio e serviços
# 46            CARAPICUIBA   -23,5687665   -46,8245205           Via Pública
# 47                S.PAULO  -23,69447524  -46,69925704           Via pública
# 48                S.PAULO   -23,5380579   -46,7311083           Via Pública
# 49                JUNDIAI  -23,20915749  -46,86562699           Via pública
#
#    DESCR_TIPO_VEICULO
# 0           AUTOMOVEL
# 1           AUTOMOVEL
# 2           AUTOMOVEL
# 3           AUTOMOVEL
# 4           MOTOCICLO
# 5           AUTOMOVEL
# 6                 NaN
# 7           AUTOMOVEL
# 8                 NaN
# 9           AUTOMOVEL
# 10          AUTOMOVEL
# 11          AUTOMOVEL
# 12                NaN
# 13          CAMIONETA
# 14                NaN
# 15          AUTOMOVEL
# 16                NaN
# 17          AUTOMOVEL
# 18          AUTOMOVEL
# 19          AUTOMOVEL
# 20          AUTOMOVEL
# 21                NaN
# 22          MOTOCICLO
# 23          AUTOMOVEL
# 24                NaN
# 25                NaN
# 26          AUTOMOVEL
# 27                NaN
# 28          AUTOMOVEL
# 29          AUTOMOVEL
# 30                NaN
# 31                NaN
# 32                NaN
# 33          AUTOMOVEL
# 34                NaN
# 35          AUTOMOVEL
# 36          AUTOMOVEL
# 37                NaN
# 38                NaN
# 39                NaN
# 40                NaN
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                NaN
# 47                NaN
# 48                NaN
# 49          AUTOMOVEL
